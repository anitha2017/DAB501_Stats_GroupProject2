# %%
import seaborn as sns
import numpy as np
import warnings
import scipy.stats as sc
warnings.filterwarnings("ignore")

# %% [markdown]
# ## A. Background Research (15 points)

# %% [markdown]
# ### Objective: Understand the fundamentals of both the binomial and normal distributions.
# ### Tasks:

# %% [markdown]
# #### 1. Describe the binomial distribution, including its parameters and its probability mass function (PMF)

# %% [markdown]
# The Binomial distribution describes the probability of having exactly k number of successes in n independent Bernoulli trials with the probability of success p and (1-p) represents the probability of failures.
#
# Probability mass function describes the probability distribution for a random, discrete variable.
#
# The binomial distribution uses PMF to calculate the probability.
#
# $$PMF(k; n , p) = {n \choose k} p^k (1-p)^{n-k}$$
#
#
# The mean, variance, and standard deviation of the number of observed successes are
#
# $$\mu=n*p, \sigma^2=n*p*(1-p), \sigma=\sqrt{n*p*(1-p)}$$
#
# The choose function is used for calculating the number of ways to choose k successes in n trials.
#
# $${n \choose k} =  \frac {n!} {k!(n-k)!}\, $$
#
# **Notes for binomial distribution**
# 1. trial should be independent,
# 2. fixed number of trials ,
# 3. outcome can be classified as success or failure on each trial,
# 4. probability of success should be same for each trial.

# %% [markdown]
# #### For example:
#
# #### Solving the below Binomial problems:
# Reference: https://www.khanacademy.org/math/ap-statistics/random-variables-ap/binomial-random-variable/e/binomial-probability
# ##### Question:
# Jamal gets ready for a basketball game by shooting 10 free-throws. Based on previous data, he has a 70% chance of making each free-throw. Assume that the results of each free-throw are independent. Whats the probability of Jamal making exactly 8 out of 10 free-throws?
#
# #### Answer:
#
# Here, number of trials is going to be number of free throws , so 'n' would be 10. probability of success on each trial would 0.70. each free-throw represents the functionality of binomial distribution. exacly 8 out of 10 free throws denotes "k". probability of failures on each trial would be 0.30.
#
# n=10
# k=10
# prob of success = 0.70
# prob of failure = 0.30
#
# $$PMF(8; 10 , 0.70) = {10 \choose 8} 0.70^8 (1-0.70)^{10-8} = {10 \choose 8}(0.70)^8(0.30)^2 = 45 * (0.70)^8 * (0.30)^2 = 0.2334744405 $$

# %% [markdown]
# The choose function is used for calculating the number of ways to choose 8 successes in 10 trials.
#
# $$ {10 \choose 8} =  \frac {10!} {8!(10-8)!}\, = \frac {8! * 9 * 10} {8! * 2!} = \frac {90} {2} = 45 $$

# %%
import math
math.comb(10,8)
# Out:
# 45

# %%
# Generate binomial data
from scipy.stats import binom
# Assign and print probability of 8 successes out of 10 trails
print(binom.pmf(k=8, n=10, p=0.70))
# Out:
# 0.2334744405000002

# %% [markdown]
# The Probability of Jamal making exactly 8 out of 10 free-throws would be 0.2334744405000002

# %% [markdown]
# The mean, variance, and standard deviation of the number of observed successes in basketball game are
#
#
# $$\mu= 10 * 0.70,   \sigma^2= 10*0.70*(1-0.70), \sigma=\sqrt{10*0.70*(1-0.70)}$$
#
# $$\mu= 7, \sigma^2 = 2.1  , \sigma=1.449137675 $$

# %% [markdown]
# #### 2. Describe the normal distribution, including its parameters and its probability density funtion on (PDF).

# %% [markdown]
# The Normal distribution describes the unimodal or symmetrical plot of data around its mean value µ, where the width of the curve is defined by the standard deviation σ. It is visually depicted as the "bell curve. Denoted as **N(µ, σ)**.
#
# x = random variable being examined
#
# f(x) = the probability function
#
# μ = the mean
#
# σ = the standard deviation
#
#      => X ~ N(μ, σ)
#
# **Probability Density Function (PDF):**
#
# $f(x) = \frac {1} {σ √2π} e^ {\frac {−1} {2} (\frac {x − μ} {σ}) ^ 2}   $ , e is the constant
#
# the denominator (${σ √2π}$), known as the normalizing coefficient, causes the total area enclosed by the graph to be exactly equal to unity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In standard normal distribution,
#
#         => X~N(μ=0, σ=1)

# %% [markdown]
# For example:
#
#     Find out the probability density for a specific value x when x = 60, μ=50, σ=10

# %% [markdown]
# $$f(60|50,10) = \frac {1} {10 √2π} e^{\frac {−1} {2} (\frac {60-50} {10}) ^ 2} $$

# %%
##mathematical calculation above equation 

import math
print(1 / (10 *math.sqrt(2*3.141592653589793)))
val1=1 / (10 *math.sqrt(2*3.141592653589793))

print(math.exp(-1/2))
val2=math.exp(-1/2)
print("probability density for a specific value x=60 => 𝑓(60|50,10) => ",val1*val2)
# Out:
# 0.039894228040143274
# 0.6065306597126334
# probability density for a specific value x=60 => 𝑓(60|50,10) =>  0.02419707245191434

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
x=60
mean=50
std_dev=10
y=norm.pdf(x, loc=mean, scale=std_dev)
print("probability density for a specific value x=60 => ", y)
# Out:
# probability density for a specific value x=60 =>  0.024197072451914336

# %% [markdown]
# The above mathematical formula and python function norm.pdf returns same value of 0.02419707245191434.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The probability density function (pdf) is used to describe probabilities for continuous random variables while for the discrete random variable, probability mass function(pmf) will be used. The binomial distribution uses PMF to calculate the probability of a single discrete value.

# %% [markdown]
# #### 3. Explain the conditions under which the binomial distribution can be approximated by the normal distribution.

# %% [markdown]
# If X is the binomial random variable, then  X∼B(n,p). The shape of the binomial distribution needs to be similar to the shape of the normal distribution.
# To ensure this, the quantities  np and  (n(1-p) or nq) must both be greater than or equal to 10 ( np>=10 and  nq>=10
#  ), In that case, the approximation is better. The sample size is considered large enough if the expected number of successes and failures are both at least 10.
#
# Mean and standard deviation of binomial distribution:
#
# $$\mu=n*p,  \sigma=\sqrt{n*p*(1-p)}$$

# %% [markdown]
# For example:
#
# Reference: https://stats.libretexts.org/Courses/Las_Positas_College/Math_40%3A_Statistics_and_Probability/06%3A_Continuous_Random_Variables_and_the_Normal_Distribution/6.04%3A_Normal_Approximation_to_the_Binomial_Distribution#:~:text=To%20ensure%20this%2C%20the%20quantities,%CF%83%3D%E2%88%9Anpq.
#
# **Example**:
# Suppose in a local Kindergarten through 12th grade (K - 12) school district, 53 percent of the population favor a charter school for grades K through 5. A simple random sample of 300 is surveyed.
#
# X=the number that favor a charter school for grades K trough 5.
# n=300
# p=0.53
#
# **X∼B(n=300,p=0.53) where n=300 and p=0.53.**
#
# n*p = 300 *0.53 = 159 >= 10, n*q = 300 * (1-0.53) = 300 * 0.47 = 141 >=10. As its large, use the normal approximation to the binomial as np >=10 and nq >= 10
#
# $$\mu=n*p = 300 * 0.53 = 159 ,  \sigma=\sqrt{n*p*(1-p)} = \sqrt{300 * 0.53 * 0.47} = 8.6447 $$
#
# The mean is 159 and the standard deviation is 8.6447. The random variable for the normal distribution is  X.
#
# **Y∼N(μ=159,σ=8.6447)**
#
# **Question:** Find the probability that at least 150 favor a charter school.
# P(X≥150) has normal approximation P(Y≥149.5)
#
# Calculator Reference:
# https://www.statskingdom.com/distribution-calculator.html
#
# For Binomial,
# P(X ≥ 150) = 0.864066. P(X≥150):1 - binomialcdf (300,0.53,149)=0.8641
#
# ![image.png](attachment:image.png)
#
# For Normal approximation,
# P(Y > 149.5) = 0.864. P(X≥150) has normal approximation P(Y > 149.5)=0.8641.
# ![image-2.png](attachment:image-2.png)

# %%
from scipy.stats import binom
prob_binom=binom.cdf(k=149, n=300, p=0.53)
print(1 -prob_binom)
# Out:
# 0.8640658827757608

# %%
print("PMF: ",binom.pmf(k=149, n=300, p=0.53))
# Out:
# PMF:  0.023605415676932435

# %%
from scipy.stats import norm

prob_normal_cdf=norm.cdf(149.5, loc=159, scale=8.6447)
print(1-prob_normal_cdf)
# Out:
# 0.8641027141360706

# %%
print("PDF: ",norm.pdf(149.5, loc=159, scale=8.6447))
# Out:
# PDF:  0.025230071810508105

# %% [markdown]
# ## Data Generation (20 points)

# %% [markdown]
# ### Objective: Generate datasets that follow the binomial distribution.
# ### Tasks:

# %% [markdown]
# #### 1. Generate and plot 1,000 samples from a binomial distribution with parameters (n = 10 ) and ( p = 0.5 ).

# %%
# Generate binomial data
from scipy.stats import binom
samplesize1_10trails = binom.rvs(n=10, p=0.50, size=1000)
print(samplesize1_10trails)
##output: Drawn samples from the parameterized binomial distribution, where each sample is equal to the number of successes over the n trials.
##In n=10 trials , how many number of successes is considered as each sample here ? so totally 1000 numbers
## probability of success should be 50%
# Out:
# [ 4  9  4  5  5  5  5  4  2  3  6  6  6  4  6  6  4  3  5  3  4  5  6  8
#   6  6  4  5  7  3  1  5  4  7  6  5  5  5  5  4  6  4  4  6  6  4  5  2
#   2  5  6  6  4  6  5  4  5  2  4  5  4  7  4  4  5  5  7  6  4  5  4  3
#   9  6  2  5  6  5  3  5  3  3  8  5  4  6  2  6  3  5  5  4  6  6  6  4
#   4  3  5  6  8  5  4  1  7  7  5  5  4  6  5  4  7  6  4  6  4  6  4  6
#   7  6  4  4  3  4  7  4  4  4  3  4  5  3  4  4  7  7  5  5  8  4  7  5
#   5  4  5  6  4  4  6  8  6  3  7  2  4  5  4  4  4  6  5  5  6  4  6  4
#   4  3  6  8  7  5  6  6  5  7  5  6  6  5  6  2  8  5  5  5  4  3  4  7
#   5  2  5  3  7  5  2  5  3  6  5  4  5  6  5  4  5  3  3  8  3  3  6  4
#   4  2  5  4  7  7  5  5  4  8  4  4  6 10  6  3  2  4  6  5  7  5  6  7
#   6  2  4  3  5  9  5  4  4  4  4  3  6  3  8  4  5  6  7  5  5  5  3  0
#   6  5  6  5  5  3  2  4  3  5  3  7  4  4  5  2  6  6  6  0  5  5  5  5
#   5  8  8  6  3  5  4  5  4  4  7  6  4  6  6  5  7  5  9  2  5  5  3  2
#   4  4  4  4  4  3  6  5  5  6  3  4  3 10  5  3  5  5  4  2  1  4  3  3
#   7  4  5  6  5  5  3  7  2  5  4  6  5  7  3  5  5  7  6  4  5  4  4  5
#   7  1  5  4  6  7  4  6  5  6  3  6  7  6  5  2  6  6  3  7  6  4  6  7
#   5  3  6  5  7  4  3  6  6  5  7  5  8  8  6  3  5  8  4  6  5  4  7  6
#   5  5  6  6  6  7  8  6  7  6  7  4  8  8  4  5  6  3  6  5  5  4  5  7
#   6  4  5  5  5  3  5  5  6  5  5  4  5  3  4  4  4  4  5  5  3  6  4  5
#   5  7  7  9  3  6  5  5  5  4  7  3  6  5  5  5  8  5  6  4  4  6  5  5
#   6  7  6  5  5  5  5  5  5  5  3  6  6  6  6  7  6  7  4  3  2  5  6  6
#   4  4  4  7  6  7  4  1  6  3  4  4  2  2  4  4  7  9  7  6  4  2  4  6
#   1  7  6  8  7  6  4  1  6  5  3  5  5  8  4  5  5  6  5  7  3  5  6  3
#   6  4  4  5  5  7  4  4  4  6  7  5  7  8  6  4  5  3  3  7  4  5  5  3
#   5  5  6  7  7  7  4  8  6  4  5  5  8  5  5  6  6  4  6  6  8  4  6  3
#   8  6  7  6  4  3  4  8  4  5  6  7  5  3  4  4  6  7  5  4  5  4  7  1
#   4  4  3  4  5  3  5  4  2  4  6  5  7  8  2  5  6  2  5  2  5  3  1  7
#   4  6  5  8  5  6  5  5  7  4  6  4  7  4  5  4  5  5  6  5  2  5  7  6
#   5  5  4  5  6  6  4  6  2  7  7  6  3  5  3  5  5  3  6  6  5  6  4  5
#   5  8  4  6  4  3  7  5  5  7  5  7  3  6  4  3  5  6  5  7  5  7  7  5
#   5  4  4  6  7  6  5  6  7  4  8  4  4  4  7  5  4  6  3  3  3  5  5  4
#   7  7  5  8  6  3  6  5  2  2  6  3  2  3  5  5  3  5  3  5  6  5  6  4
#   2  7  7  3  5  4  4  6  4  5  6  4  6  7  6  3  5  5  4  2  3  4  5  3
#   4  3  8  5  5  5  6  4  7  6  3  6  4  4  4  4  6  6  3  2  7  5  4  4
#   7  5  7  4  5  3  7  6  5  4  3  4  6  5  4  6  6  7  4  5  6  5  5  5
#   4  8  6  6  4  6  6  3  4  5  7  5  6  5  3  4  7  3  8  4  6  6  5  4
#   3  6  6  7  4  1  2  5  3  6  5  4  6  4  5  3  7  3  5  4  6  7  5  4
#   6  6  5  6  6  5  4  6  7  2  5  4  6  5  5  4  5  3  5  4  6  6  5  7
#   5  6  4  4  8  5  6  6  4  5  4  7  4  7  5  5  4  3  8  1  6  4  6  5
#   4  2  5  6  6  3  4  4  4  3  5  5  6  5  6  4  5  4  4  6  6  5  5  5
#   5  8  5  8  3  5  5  3  7  7  6  6  6  7  5  6  7  7  5  8  2  7  5  4
#   5  7  9  5  1  7  7  5  3  7  7  5  7  8  3  6]

# %% [markdown]
# #### 2. Generate and plot 1,000 samples from a binomial distribution with parameters ( n = 100 ) and ( p = 0.5 ).

# %%
# Generate binomial data
from scipy.stats import binom
samplesize2_100trails = binom.rvs(n=100, p=0.50, size=1000)
print(samplesize2_100trails)
##output: Drawn samples from the parameterized binomial distribution, where each sample is equal to the number of successes over the n trials.
##In n=100 trials , how many number of successes is considered as each sample here ? so totally 1000 numbers
## probability of success should be 50%
# Out:
# [47 50 44 46 50 62 44 50 48 56 48 56 49 42 51 43 50 45 54 46 50 51 60 56
#  49 50 56 51 43 61 46 53 49 52 54 47 47 53 46 55 53 49 45 39 52 60 47 50
#  56 51 56 44 50 52 46 41 47 50 56 44 53 53 47 52 47 44 46 49 41 56 41 54
#  53 43 51 50 45 49 47 50 49 51 56 53 54 50 54 49 46 46 58 57 56 49 52 52
#  50 48 47 57 54 43 58 53 52 45 57 57 38 43 48 50 44 53 53 48 49 52 50 56
#  60 47 45 41 56 56 53 48 61 45 52 58 47 57 48 48 61 50 47 50 46 48 51 46
#  51 50 47 54 46 43 55 49 47 63 52 52 48 43 47 49 56 51 43 53 60 47 52 42
#  48 45 48 53 46 57 50 54 50 53 50 48 49 46 40 49 51 46 49 47 51 51 45 44
#  53 52 49 53 48 45 54 45 53 54 48 46 40 51 57 57 53 49 52 51 59 59 41 50
#  54 48 50 53 42 56 44 54 45 51 46 45 43 49 47 57 44 54 45 56 44 51 40 58
#  53 50 52 53 49 43 49 56 50 44 47 62 34 49 46 54 53 48 46 51 58 61 46 43
#  47 47 61 52 49 51 43 51 48 53 42 55 50 48 53 53 48 52 47 47 56 50 48 52
#  47 54 49 41 53 51 46 58 62 46 40 49 54 42 46 42 48 51 47 46 48 61 53 59
#  49 54 51 38 49 51 43 54 47 51 51 50 50 49 49 62 40 55 50 55 51 44 43 57
#  58 61 55 49 45 56 56 53 53 55 39 47 61 51 51 51 49 41 56 53 54 41 52 52
#  43 51 55 53 57 48 45 36 48 48 56 41 47 45 51 53 42 46 49 52 50 48 46 60
#  51 53 46 60 54 61 49 42 47 48 53 54 51 47 48 51 38 46 57 49 50 50 54 59
#  49 43 53 49 54 49 43 50 45 39 56 51 46 52 48 59 54 50 46 47 57 41 45 47
#  55 54 41 61 48 60 53 45 47 48 46 53 44 52 55 46 51 47 46 46 44 47 50 54
#  57 54 44 52 59 45 48 50 47 47 62 61 47 53 53 50 50 55 52 52 55 54 49 59
#  47 44 45 44 47 49 54 47 57 50 54 52 47 49 46 58 47 55 52 50 54 43 55 45
#  56 52 43 47 45 46 36 49 51 45 51 53 50 50 61 50 55 53 48 52 53 44 44 47
#  46 51 44 49 49 47 47 44 54 49 55 39 47 43 44 48 59 47 39 52 54 42 42 52
#  53 55 51 46 53 52 47 43 53 44 54 50 47 51 59 49 53 42 44 57 50 51 56 52
#  53 52 48 55 50 65 49 50 48 46 51 43 50 54 56 39 50 39 40 50 44 51 51 55
#  49 50 51 51 51 49 55 51 53 54 45 57 50 49 60 45 49 47 55 56 58 53 39 49
#  52 55 49 51 46 56 52 55 50 47 48 48 52 44 46 48 42 53 48 52 44 47 44 47
#  46 44 53 53 49 47 51 45 46 54 45 48 54 54 49 44 50 51 54 56 52 43 53 50
#  54 53 53 46 39 45 39 44 44 47 47 47 49 53 52 59 42 48 42 49 61 48 50 57
#  56 53 44 50 48 48 49 44 61 48 45 59 41 46 41 41 50 48 46 45 45 48 57 50
#  51 46 58 46 49 49 54 54 52 55 54 48 49 51 44 50 50 57 52 48 46 43 52 59
#  49 55 50 61 50 45 49 43 46 50 44 51 44 42 44 53 57 40 47 40 37 52 53 50
#  56 53 45 48 45 49 49 49 52 49 46 53 51 52 56 54 47 46 49 47 53 57 50 43
#  46 39 54 48 50 54 47 46 47 43 44 50 43 60 54 53 45 54 48 45 52 44 52 46
#  42 49 44 48 51 47 54 53 50 53 47 52 41 53 41 50 51 52 55 50 52 51 43 48
#  43 53 52 58 52 49 44 57 55 57 57 55 62 45 47 54 53 51 49 47 51 50 60 44
#  50 53 47 49 59 42 48 52 47 48 47 54 46 51 51 50 55 50 47 55 54 57 50 54
#  54 39 48 49 54 51 49 55 47 48 49 46 43 55 43 50 44 54 43 47 45 53 53 56
#  52 51 51 46 59 48 51 60 57 52 51 53 46 43 54 51 50 43 51 47 46 45 51 53
#  56 46 45 58 57 49 55 52 50 50 51 50 56 50 45 50 50 46 52 49 47 48 49 58
#  58 41 54 47 56 52 50 55 56 47 63 47 46 48 49 60 53 55 59 50 49 53 48 42
#  46 37 56 51 56 39 49 46 49 47 47 46 46 55 45 53]

# %% [markdown]
# #### 3. Generate and plot 1,000 samples from a binomial distribu􀆟on with parameters ( n = 100 ) and ( p = 0.1 ).

# %%
# Generate binomial data
from scipy.stats import binom
samplesize3_100trails = binom.rvs(n=100, p=0.10, size=1000)
print(samplesize3_100trails)
##output: Drawn samples from the parameterized binomial distribution, where each sample is equal to the number of successes over the n trials.
##In n=100 trials , how many number of successes is considered as each sample here ? so totally 1000 numbers
## probability of success should be 10%
# Out:
# [10 10  7 12 11 10  5  3  9  8  8  7  7  5  8 15  9 10  7 12  7 10 10  7
#   8  5 11  8  8 10 12  5  4 14 14  8 10 10  9 14  5  7 12 14 15 15 12  9
#   9 12  9  8  6 13  8 10 11  8  5  8  6 11  7  5  8  8  3 14 14  6 15  7
#  17 14  7  8  9 10  8 15 10 12  6  8  9 11  8 11  8 14  9  9  9 14 10 14
#   4 10  5 12 11 12 10  6  7  6 14  6 13 13 14  8  5  9  3  6 17  5  7 17
#   9 11  7  6 10 15 10 14 12 10  9  7  6  6 11 12 12 11 10  6  9 10 13 12
#  15  8 10  6  6  7 12  8 12 13  7 11 10  7  8 12 11 11 18 12 16  8 13 11
#  11 14 13  9 14 11 12  9  9 10  4 10  9  9 10 10  8  3 10 12  7 11 14 14
#  20  5 13 12 14 10  7  7 12  9 13  7 10 10 17 11  9  7  9 17  4 12 10 17
#   9  7  8  4  7 12  9 13 10 14  9 14  7 13 12 10 11 11 10 10  8  6  9 10
#   9  8 10 12  2  7  9 15 10  7 11 13  4 12 11  8 11 11  4  6 10 11  8 11
#  15 12 13 16 13 10 11  7 15 11  7  8 12 10 14  5 11  4  7 13  6 14  8  9
#  12  7  7 13  9 11 12 11  5  7  9 15 11  8  8 10 14 10 11  8 14 11  6 10
#   6 14 13  4  5  9  8  9  8 12  9  7 10  6  8  9  7 13 12 14 11  5  5  7
#   4  6 10  7 12 13 16 10  7 15 12 11  5  4 13 11 13 11 10  6 12 13  6  9
#   6  9 12 13 14  9  6 12 17 14 10  8  8 12 10 10 11 11  4 10  4  9 10 15
#  13  8  9  6 10 14  8 13 14 16  9  8 15 15  4  8  6 10  9 11 15  9 13  6
#  11 12  8  8 10 10 10 11 12  9  5  8  8  7 16  9  9  7 19  7 10 13 11 12
#  12  8 14  9  9 15 12  8 11 12 11  7 11  8 12 12 12 11  9  8 12 11  6  8
#   8  8  6 11 11 14 10  7  8 13  8  9  7  9  7  8 14 11  6 14 13  7 11 13
#   7 10  7 15 11 12  8 12 14 12  8 10  4 14  6  7 15  9  3 13  7 10 14  9
#   5  7 11  3 15  7 12  9 10  7 15 12 10 15  6 17  8 13 12 11  8 10 13  9
#   9 13 18 16 12  7 14  6 14  8  7  7 16 13 10  7 13 11 15 10  9 13 10  8
#   4 11 11 11 12  6 11 15 11  9 12  9 17 14 13  9 13  5 10  9  8  7 11 11
#  13  9 12 12 11  5 11  9  9 11 13 10 15 13 12  6  6 10  9  9  7 12  6 10
#   5 14 13 10 11  8  9  9 10  9 10 11  9  9 11  6 10 10  6 12 10 13 12  9
#  12  7  7  8 16  6 13  7  6  5  9 12  7 11 14  6  9  7  6  4  8 12 10  6
#  12 13  9 15  5  7  7  6  9  9  7 15 15  8 11  6 10  5  6  5 16 12 12 14
#  11  8 11 12 13 13  6  7  9  8  9  9 11  6 12  7  9 10  9 12 11 16  9 10
#  16 17 14  8  5 13 14  5  9  2 14  8 10 13 12 11 12 11  8 14 13  5 10 12
#   4  5 13  9  8 15  7 12 19 16 10  8  6 13 13 11 11 10 10  8 14 15  4 10
#   7 10 10 11 11 12 11 10 14 10 10 11  6 13 14  8 11  9  5  5 13 10  7 11
#   8  9 11 10 11 11  9  6 12  9 12 11  6 13  7  8 13 10 16 10 11 11  4 12
#  14 10 11 13 10  7  8  5  6 11 13  8 12 12 12 12  9 10  7 10 11 13  6 14
#   6  9 15  7 11 10  8 11 13  9 12  8 13 11 11 11 12 13  7  8  7 11  9 11
#   8 13  8 12  6 10  8 12  8  8  6  8  9 11 17 12  5 10 16  7  6 11  9 18
#   9  8 11 14  8 14 14 12 11 10  8 10  8  9  6  8 12  6 15 12  8  8 15  9
#   8  9 10  8  7 10 12  8 15  9  5  9  9  7  8  6 12  7 10  6  8 11  8 16
#   8  9 12 16 14  8 12  5 15  9  9 11 17  8  7  7  6 11  9  8 13  8  7  9
#  10 12 11 14  9 10 11  4 11  7  8 13 11 11  7  9  6  9 10 14  7 11 12 18
#   8  9 10 16  8 13  4 10  9  9  5 12 12 14  7  9  6 12 10  8 10  9 10 10
#  15 18 11 10 10 16 16  6 15 10 10  9 17 10  8 12]

# %% [markdown]
# ## C. Data Analysis (25 points)

# %% [markdown]
# ### Objective: Analyze and visualize the generated data to observe the convergence of the binomial to the normal distribution.
# ### Tasks:

# %% [markdown]
# #### 1. Calculate and plot the histograms for each of the datasets generated in the previous section.

# %%
# Plot the distribution
plt.hist(samplesize1_10trails)
plt.title("10 trails, probability of success is 50% , sample size is 1000")
plt.show()

# %%
# Assign and print probability of 8 or less successes
prob1 = binom.cdf(k=8, n=10, p=0.50)
print("Binomial CDF: ",(1-prob1))
# Assign and print probability of all 10 successes
prob2 = binom.pmf(k=10, n=10, p=0.50)
print("Binomial PMF: ",prob2)
# Out:
# Binomial CDF:  0.0107421875
# Binomial PMF:  0.0009765625

# %%
# Plot the distribution
plt.hist(samplesize2_100trails)
plt.title("100 trails, probability of success is 50% , sample size is 1000")
plt.show()

# %%
# Assign and print probability of 8 or less successes
prob1 = binom.cdf(k=8, n=100, p=0.50)
print("Binomial CDF: ",'{:.20f}'.format(1-prob1))
# Assign and print probability of all 10 successes
prob2 = binom.pmf(k=10, n=100, p=0.50)
print("Binomial PMF: ",'{:.20f}'.format(prob2))
# Out:
# Binomial CDF:  1.00000000000000000000
# Binomial PMF:  0.00000000000000001366

# %%
# Plot the distribution
plt.hist(samplesize3_100trails)
plt.title("100 trails, probability of success is 10% , sample size is 1000")
plt.show()

# %%
# Assign and print probability of 8 or less successes
prob1 = binom.cdf(k=8, n=100, p=0.10)
print("Binomial CDF: ",(1-prob1))
# Assign and print probability of all 10 successes
prob2 = binom.pmf(k=10, n=100, p=0.10)
print("Binomial PMF: ",prob2)
# Out:
# Binomial CDF:  0.679126111637159
# Binomial PMF:  0.13186534682448792

# %% [markdown]
# #### 2. Overlay a normal distribution curve on each histogram, using the mean and standard deviation of the binomial dataset as parameters for the normal distribution.

# %%
import numpy as np
import scipy. stats as stats
samplesize1_10trails_mean = np.array(samplesize1_10trails).mean()
samplesize1_10trails_std_dev = np.array(samplesize1_10trails).std()
print("First Step, 10 trails, prob=0.5, size = 1000 => Mean Value: ",samplesize1_10trails_mean)
print("First Step, 10 trails, prob=0.5, size = 1000 => Std Value: ",samplesize1_10trails_std_dev)
# Out:
# First Step, 10 trails, prob=0.5, size = 1000 => Mean Value:  4.993
# First Step, 10 trails, prob=0.5, size = 1000 => Std Value:  1.5540112612204584

# %%
# Creating a range of x values from mean - 4*std_
x = np.linspace(samplesize1_10trails_mean - 4*samplesize1_10trails_std_dev, samplesize1_10trails_mean + 4*samplesize1_10trails_std_dev, 1000)

# Calculating the normal distribution values
y = stats.norm.pdf(x, samplesize1_10trails_mean, samplesize1_10trails_std_dev)

# Plotting the normal distribution
plt. figure (figsize=(6, 6))
plt. plot(x, y, label= 'Normal Distribution')
plt.hist(x = samplesize1_10trails, density = True)
plt.title('n=10, p=0.5, size =1000, N(µ=4.993, σ= 1.5540112612204584)')
plt.xlabel( 'Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import scipy. stats as stats
samplesize2_100trails_mean = np.array(samplesize2_100trails).mean()
samplesize2_100trails_std_dev = np.array(samplesize2_100trails).std()
print("Second Step, 100 trails, prob=0.5, size = 1000 => Mean Value: ",samplesize2_100trails_mean)
print("Second Step, 100 trails, prob=0.5, size = 1000 => Std Value: ",samplesize2_100trails_std_dev)
# Out:
# Second Step, 100 trails, prob=0.5, size = 1000 => Mean Value:  49.847
# Second Step, 100 trails, prob=0.5, size = 1000 => Std Value:  4.996157623614371

# %%
# Creating a range of x values from mean - 4*std_
x = np.linspace(samplesize2_100trails_mean - 4*samplesize2_100trails_std_dev, samplesize2_100trails_mean + 4*samplesize2_100trails_std_dev, 1000)

# Calculating the normal distribution values
y = stats.norm.pdf(x, samplesize2_100trails_mean, samplesize2_100trails_std_dev)

# Plotting the normal distribution
plt. figure (figsize=(6, 6))
plt. plot(x, y, label= 'Normal Distribution')
plt.hist(x = samplesize2_100trails, density = True)
plt.title('n=100, p=0.5, size =1000, N(µ=49.847, σ= 4.996157623614371)')
plt.xlabel( 'Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import scipy. stats as stats
samplesize3_100trails_mean = np.array(samplesize3_100trails).mean()
samplesize3_100trails_std_dev = np.array(samplesize3_100trails).std()
print("Third Step, 100 trails, prob=0.1, size = 1000 => Mean Value: ",samplesize3_100trails_mean)
print("Third Step, 100 trails, prob=0.1, size = 1000 => Std Value: ",samplesize3_100trails_std_dev)
# Out:
# Third Step, 100 trails, prob=0.1, size = 1000 => Mean Value:  9.961
# Third Step, 100 trails, prob=0.1, size = 1000 => Std Value:  3.0827713181486556

# %%
# Creating a range of x values from mean - 4*std_
x = np.linspace(samplesize3_100trails_mean - 4*samplesize3_100trails_std_dev, samplesize3_100trails_mean + 4*samplesize3_100trails_std_dev, 1000)

# Calculating the normal distribution values
y = stats.norm.pdf(x, samplesize3_100trails_mean, samplesize3_100trails_std_dev)

# Plotting the normal distribution
plt. figure (figsize=(6, 6))
plt. plot(x, y, label= 'Normal Distribution')
plt.hist(x = samplesize3_100trails, density = True)
plt.title('n=100, p=0.1, size =1000, N(µ=9.961, σ= 3.0827713181486556)')
plt.xlabel( 'Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### 3. Discuss the fit of the normal curve to the histograms and how the fit changes with different binomial parameters.

# %% [markdown]
# By looking at the above three histograms and its normal curve, second one with n=100, p=0.5, size =1000, N(µ=49.847, σ= 4.996157623614371) looks more normal and it fits perfectly with binomal parameters.
# The more we increase the number of trails from 10 to 100, its more near to normal distribution with probability of success is 0.5.
#
# First one n=10, p=0.5, size =1000, N(µ=4.993, σ= 1.5540112612204584) looks not nearly normal as number of trails are less that would not cause normal curve.
# Third one n=100, p=0.1, size =1000, N(µ=9.961, σ= 3.0827713181486556) looks little bit off as its probability of success is only 0.1.
#
# Also by looking at cumulative distribution function and probability density function , there are high number of probability which is Binomial CDF:  1.0 (100%) to get more than 8 number of success in the second normalized structure whereas others are having less number of probability

# %% [markdown]
# ##  Theoretical Exploration (20 points)

# %% [markdown]
# ### Objective: Dive deeper into the mathematical aspects of the distributions.
# ### Tasks:

# %% [markdown]
# #### 1. Derive the mean and variance for the binomial distribution.

# %% [markdown]
# Mean and standard deviation of binomial distribution:
#
# $$\mu=n*p,  \sigma=\sqrt{n*p*(1-p)}$$

# %% [markdown]
# #### 2. Explain the Central Limit Theorem and its significance in the approximation of the binomial distribution by the normal distribution.

# %% [markdown]
# The sampling distribution will approach a normal distribution as the size of the sample increases which phenomenon is known as Central Limit Theorem.
# samples must be taken randomly and are independent. For example, randomly picking sales deals with replacement.
#
#
#
# Generally, A sample size of at least 30 (n>=30) is required for the central limit theorem to apply. If a large sample (usually n>=30) is taken from a nonnormal distribution with mean m and
# standard deviation s then according to the central limit theorem the sample mean x follows
# the normal distribution with mean µ  , standard deviation ${\sigma}$, standard error $\frac {\sigma} {\sqrt{n}}$.
#
# Central Limit Theorem equation: $\bar {X} $ ~ N(µ,$\frac {\sigma} {\sqrt{n}}$)
#
# This is a very important
# theorem because knowing the distribution of x we can make inferences about the
# population’s mean, even if this population does not follow the normal distribution.
#
#
#
# The central limit theorem, or CLT, applies to other summary statistics as well. If we take the standard deviation of 6 rolls 5000 times, the sample standard deviations are distributed normally, centered around one-point-nine, which is the distribution's standard deviation.
#
#
#
# Another statistic that the central limit theorem applies to is proportion. Let's sample from a die 10,50,100 times with replacement and repeat the iterations for about 5000 and see its changes to normal distribution.

# %%
from numpy.random import seed
from numpy.random import randint
from numpy import mean
seed(1)
dice_rolls=randint(1,7,100)
print(dice_rolls.shape)
print(dice_rolls)
print(mean(dice_rolls))
# Out:
# (100,)
# [6 4 5 1 2 4 6 1 1 2 5 6 5 2 3 5 6 3 5 4 5 3 5 6 3 5 2 2 1 6 2 2 6 2 2 1 5
#  2 1 1 6 4 3 2 1 4 6 2 2 4 5 1 2 4 5 3 5 1 6 4 2 3 1 5 2 3 3 2 1 2 4 6 5 4
#  6 2 4 1 1 3 3 2 4 5 3 1 1 2 2 6 4 1 1 6 6 5 6 3 5 4]
# 3.38

# %%
sample_means10 = [randint(1,7,10).mean() for i in range(0, 5000)]
sample_means50 = [randint(1,7,50).mean() for i in range(0, 5000)]
sample_means100 = [randint(1,7,100).mean() for i in range(0, 5000)]

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.hist(sample_means10, edgecolor = 'black', linewidth = 1.2, bins = 25, color = 'aqua')
plt.title("sample size of 10")
plt.show();
plt.hist(sample_means50, edgecolor = 'black', linewidth = 1.2, bins = 25, color='pink')
plt.title("sample size of 50")
plt.show();
plt.hist(sample_means100, edgecolor = 'black', linewidth = 1.2, bins = 25, color = 'violet')
plt.title("sample size of 100")
plt.show();

# %%
print("Mean of Sample mean size of 10 in 5000 iterations=>",mean(sample_means10))
print("Mean of Sample mean size of 50 in 5000 iterations=>",mean(sample_means50))
print("Mean of Sample mean size of 100 in 5000 iterations=>",mean(sample_means100))
# Out:
# Mean of Sample mean size of 10 in 5000 iterations=> 3.4992199999999998
# Mean of Sample mean size of 50 in 5000 iterations=> 3.5037839999999996
# Mean of Sample mean size of 100 in 5000 iterations=> 3.5063920000000004

# %% [markdown]
# ## E. Real-World Application (15 points)

# %% [markdown]
# ### Objective: Explore a real-world scenario where the binomial distribution and its approximation by the normal distribution can be applied
#
# ### Tasks:

# %% [markdown]
# #### 1. Choose a real-world scenario or dataset that can be modelled using the binomial distribution (e.g., number of successes in a series of Bernoulli trials).

# %%
def perform_bernoulli_trials(n, p):
    """Perform n Bernoulli trials with success probability p
    and return number of successes."""
    # Initialize number of successes: n_success
    n_success = 0

    # Perform trials
    for i in range(n):
        # Choose random number between zero and one: random_number
        random_number = rng.random()
        print(random_number)
        # If less than p, it's a success so add one to n_success
        if random_number < p:
            n_success += 1

    return n_success

# %%
prob_positive = ct_df_2021['Number of molecular positives'].sum()/ct_df_2021['Number of molecular tests'].sum()
prob_positive
# Out:
# 0.04878205778146878

# %% [markdown]
# #### 2. Analyse the dataset or scenario using both the binomial and normal distributions.

# %% [markdown]
# #### 3. Discuss the appropriateness of using the normal approximation in the chosen scenario.

# %% [markdown]
# ## F. Presentation & Report (5 points)
# ### Objective: Present findings in a clear and concise manner.
# ### Tasks:
# #### 1. Compile all findings, visualizations, and explanations into a comprehensive report.
# #### 2. Ensure that the report is structured, clear, and follows academic standards.

# %%
import numpy as np
bin_dist=np.random.binomial(n=10,p=0.50)
##result - number of success

# %%
bin_dist
# Out:
# 2

# %%
# Out:
# 2.0

# %%
# Out:
# 0.0

# %%
# Out:
# [ 3  4  5  4  9  5  2  1  6  6  5  5  6  5  6  7  4  5  7  6  7  6  3  4
#   3  5  4  1  5  2  6  2  6  5  4  6  6  8  6  8  5  5  4  5  5  3  7  8
#   6  5  5  4  4  2  7  5  5  5  6  4  5  5  4  7  5  6  4  6  7  4  7  4
#   6  7  5  4  3  5  3  7  5  3  3  5  6  4  1  2  4  7  6  5  5  4  5  4
#   5  7  2  2  3  3  4  3  3  6  4  6  5  9  5  2  4  4  6  3  2  3  5  4
#   2  6  7  5  2  6  4  4  4  6  5  2  5  4  6  4  6  6  7  5  2  5  3  3
#   6  6  6  6  5  4  7  7  5  4  5  8  4  6  5  3  1  4  3  9  4  8  4  6
#   7  3  3  5  5  3  5  3  5  8  2  5  5  1  6  6  1  4  4  6  4  3  6  5
#   5  2  6  8  6  2  8  7  7  3 10  9  4  6  5  3  7  6  4  6  6  7  5  4
#   4  7  2  4  5  3  7  5  6  5  4  6  6  6  5  5  5  7  6  6  5  2  8  7
#   8  5  6  3  5  5  5  5  5  4  5  2  3  5  5  6  4  7  6  6  4  5  4  4
#   3  6  5  5  6  5  6  6  7  2  5  5  4  6  5  6  4  3  4  5  5  5  4  6
#   2  5  2  3  2  6  5  6  5  4  5  4  6  5  3  6  2  7  5  5  7  6  3  5
#   6  3  4  3  3  3  7  5  5  3  6  6  5  2  5  5  4  5  4  2  5  3  9  2
#   2  4  5  5  2  5  5  5  4  7  7  3  2  7  7  7  5  6  4  5  6  6  6  3
#   7  5  5  4  6  5  4  4  6  5  4  6  4  6  2  6  8  5  5  6  7  5  8  8
#   3  2  6  4  2  6  7  5  7  6  7  3  6  3  4  6  4  2  4  6  3  7  3  3
#   5  5  6  4  8  6  4  8  6  5  2  4  6  4  4  6  7  5  4  6  5  4  6  4
#   4  4  6  6  3  3  4  5  3  7  6  4  1  2  5  7  6  6  6  5  5  7  3  5
#   4  4  3  6  6  4  4  2  3  5  5  4  7  7  4  6  3  5  4  8  5  3  6  6
#   6  5  4  4  8  3  5  2  6  3  4  7  6  5  6  5  7  6  4  5  2  3  2  5
#   5  4  5  9  7  8  6  5  6  6  7  3  5  6  4  5  6  8  4  5  6  5  3  5
#   4  4  5  5  4  6  3  5  6  3  4  4  6  3  4  3  4  6  6  4  5  4  4  7
#   8  5  4  4  7  3  4  7  4  4  4  8  4  6  8  7  5  7  4  4  4  7  3  7
#   2  7  5  5  1  3  6  5  5  8  5  7  5  5  7  6  3  6  3  6  3  5  5  2
#   4  7  4  5  7  3  5  7  6  5  5  3  4  8  5  5  4  8  5  5  6  7  5  6
#   3  5  6  7  4  5  6  7  2  3  4  5  5  5  5  4  5  8  3  5  3  2  5  4
#   8  4  5  4  5  3  5  8  5  2  3  5  4  3  4  4  5  4  3  6  6  6  6  6
#   8  6  8  3  7  4  5  4  3  4  6  7  5  5  5  5  3  5  6  4  6  7  4  4
#   6  4  5  4  5  3  7  6  6  5  5  7  5  3  4  8  5  5  5  6  4  5  5  5
#   5  4  7  5  4  6  5  4  4  5  5  5  6  4  2  4  4  6  5  7  5  5  5  6
#   7  5  3  6  4  4  6  6  1  6  4  6  4  4  5  6  3  6  5  4  8  4  4  3
#   4  4  4  7  6  6  4  3  3  4  6  6  6  6  7  7  2  6  3  6  3  4  2  6
#   6  4  2  8  3  6  5  3  5  7  6  6  5  1  5  5  3  6  6  4  5  7  7  4
#   6  3  7  6  5  6  5  5  4  3  2  7  6  6  1  5  6  5  4  6  5  7  6  4
#   5  6  5  2  2  4  2  8  7  5  6  6  7  8  3  2  4  3  3  7  5  6  7  8
#   5  6  4  5  7  2  5  4  3  5  2  4  2  7  2  5  5  4  2  3  5  3  4  6
#   5  5  6  5  4  4  7  5  6  4  4  4  4  4  5  1  8  4  6  6  6  6  8  7
#   7  7  8  7  5  4  7  3  6  3  5  6  7  3  5  4  2  6  4  7  5  5  6  7
#   4  7  3  5  4  5  5  5  7  7  5  7  3  6  7  3  5  3  3  6  7  7  4  5
#   7  4  5  7  4  6  6  6  8  3  7  4  3  7  4  7  3  6  4  7  4  6  6  6
#   7  4  7  6  5  3  8  4  2  7  5  5  4  7  5  3]

# %%
# Plot the distribution
sns.distplot(sample1_trials)
# Out:
# <Axes: ylabel='Density'>

# %%
# Generate binomial data
from scipy.stats import binom
sample2_trials = binom.rvs(n=100, p=0.50, size=1000)
print(sample2_trials.shape)
# Out:
# (1000,)

# %%
# Plot the distribution
sns.distplot(sample2_trials)
# Out:
# <Axes: ylabel='Density'>

# %%
mean = np.array(sample2_trials).mean()
print(mean)
std = np.array(sample2_trials).std()
print(std)
# Out:
# 50.02
# 4.979518048968193

# %%
x = np.arange(30,75,5)

# %%
plt.figure(figsize=(12,8))
#sns.histplot(sample2_trials)
plt.plot(x,sc.norm.pdf(x,mean,std))
plt.show()

# %%
import matplotlib.pyplot as plt 
from scipy.stats import norm 
  
  
plt.plot(sample2_trials[0], norm.pdf(sample2_trials[0], mean, std)) 
plt.show()

# %%
# Generate binomial data
from scipy.stats import binom
sample3_trials = binom.rvs(n=100, p=0.1, size=1000)
print(sample3_trials.shape)
sample3_trials
# Out:
# (1000,)
# array([10, 10, 10,  7,  7, 15,  8,  6, 12,  5,  9,  7, 10, 13, 12,  6,  9,
#         6, 12, 10, 10,  9, 11, 10, 14, 11,  9,  7, 11,  8,  9,  8, 10, 17,
#        15,  8, 17, 12,  7,  5, 14, 16,  8,  8, 11,  8, 14,  4,  7, 13, 11,
#         7, 11,  8, 14, 11,  6,  8,  9, 10,  6,  8,  8, 15, 10, 12, 10, 11,
#         9, 11, 12,  8,  8, 16, 10, 12, 12,  8,  9,  7,  8,  7, 10,  5, 13,
#        10, 12,  8, 16, 13, 12,  8, 11, 17, 11, 14,  8, 12,  9, 14,  8,  5,
#         8, 13,  9,  9,  8,  8,  6, 11,  7, 12, 17, 15, 14, 14,  5, 12, 11,
#         4, 12,  9, 13,  5,  9,  9, 10,  8, 10, 14,  7,  7,  5, 11, 13,  7,
#         8, 12,  7, 11, 12,  7,  6, 14,  3,  8, 12, 10, 13, 13, 10,  5, 11,
#         4, 11,  7,  7, 11, 10,  8, 17,  9,  6, 10,  5,  9,  8, 11, 11,  8,
#        10,  9, 14, 16, 12,  8,  9, 11, 13, 11,  9, 12,  5, 11,  8, 11, 12,
#         3, 11,  7, 15, 13, 12, 13,  6,  7,  8,  5,  7,  6, 12, 16,  8, 11,
#         8, 13, 11,  8, 12, 10,  9, 11,  6, 11,  9,  8, 11,  9, 14,  8, 19,
#        10,  4,  5,  8,  9, 10,  4, 10, 10,  7,  7,  8, 11, 12,  6, 13,  7,
#         9,  4,  4, 10,  9,  8,  8, 10,  6, 13, 11,  6, 15,  7,  8,  9,  8,
#        12, 14,  8,  8,  8,  7, 11,  9, 10, 12,  9,  8,  8, 10, 13, 11, 13,
#         8, 11,  6,  8,  6, 17, 10, 11,  6,  5,  7,  6,  9,  9, 14, 21,  7,
#        14,  8, 11, 11, 17,  6, 11, 12,  8, 10, 10,  9,  7,  7, 10, 13,  9,
#        10, 11, 10, 10, 13, 10, 12, 10, 11, 13, 10,  7, 11,  9,  8,  7, 14,
#        13, 11, 13, 12, 11, 12, 14,  6, 12, 13,  9,  9,  9,  7, 11,  6,  7,
#         7,  8, 11, 16, 10,  9, 10, 10, 10, 12,  8, 11,  7, 10, 14,  6, 10,
#        12,  8, 10, 13, 10,  8, 13,  7, 18, 12, 11, 12, 10, 11, 13,  8,  6,
#        10,  8,  9,  7, 10,  7, 10, 12,  9,  5, 10,  9, 14, 11,  9, 11,  4,
#         9, 12, 10, 12, 15,  8,  6,  9, 12, 15,  6,  7,  9, 10,  9, 16, 11,
#        11,  9, 14, 12,  9, 12,  7,  8, 11,  9, 11,  8,  9,  9,  4,  8,  8,
#         9,  9,  9, 13, 10, 10,  5,  7, 11, 10,  6, 10, 12, 13, 12, 12, 12,
#        10,  9,  7,  7,  6, 14, 14, 13, 16,  9, 19,  5,  5, 14, 12, 13,  7,
#        15, 10, 12,  4, 11, 11, 20,  9, 12, 18,  7, 13,  8, 12,  8, 11, 10,
#        12,  6, 16, 10,  8, 11,  6, 11, 12,  7,  8,  7, 11, 12, 11,  8,  9,
#        12, 17, 14, 13,  9,  8, 10,  9,  9,  5, 10, 13,  5,  9, 11,  8, 14,
#         8, 13,  9, 14, 10,  8, 10,  6, 13, 13, 10, 10,  7, 11,  9,  7, 10,
#         7,  8,  7, 10, 12,  9, 10,  9,  8, 10, 11, 10, 11,  7, 12,  5, 13,
#        10,  6, 15, 18, 14, 15, 12,  6, 10, 11, 10,  8,  6, 10,  9, 13, 11,
#        12,  8,  9,  8,  4, 12, 10, 10,  6,  6,  8, 12, 14, 10,  7, 14,  4,
#        10,  7,  7,  6, 14, 10,  5, 10, 11, 10,  9,  7,  8,  9,  9,  8, 12,
#         7, 10, 15, 10,  8, 10,  9, 13,  9,  6, 10,  9,  8, 13, 14,  9,  5,
#         7, 11,  3,  8,  8,  6,  9, 11, 11, 15, 11,  8, 13,  9,  7,  6, 13,
#        12, 10,  7, 10, 11, 11, 11,  9, 12,  8,  5, 16,  7, 14,  8,  8,  9,
#         9,  9,  2, 15, 10, 16,  7, 11,  9, 11,  8, 12, 15,  7, 11, 11,  5,
#        13,  5, 14,  9,  6, 12,  8,  8,  6, 11, 10,  5, 12,  5,  7,  9, 12,
#         8, 11,  9,  9,  9, 12, 12,  9,  8,  9, 10,  6,  5, 11,  9, 11, 14,
#         7, 13, 13, 11,  5, 11, 16,  7,  5, 15,  5, 10, 11, 11, 13,  9, 12,
#        10, 13, 18, 11,  8,  6,  9, 14,  9, 11,  9,  5,  9,  7,  9, 16, 10,
#        15, 11, 11, 10, 11, 10,  9, 11, 11,  7,  7,  8,  9, 10,  9,  6,  8,
#        14, 11,  6,  7,  9,  7, 12,  7,  7,  7,  5, 10, 15, 11, 10, 14, 12,
#        11, 13,  9,  8,  8,  7, 10, 10, 10,  7, 12, 10, 12, 10,  9, 12, 15,
#         5, 10, 12,  4,  9, 17, 12,  9, 12, 13, 12, 11, 11,  5, 10, 13, 11,
#         8,  7, 11, 11,  7, 11,  9, 12, 12, 12,  6,  9,  9,  9,  9, 11, 11,
#         7, 12,  4,  6,  5, 15, 17,  7, 11, 12, 10, 14,  9,  9,  9, 10,  3,
#         9, 12, 10,  7, 13, 12, 14,  9, 10, 10, 11,  6, 12, 12, 14, 12,  2,
#        11, 15,  9, 10, 16,  8, 14, 11, 13, 12,  7,  9,  7,  9, 10, 10, 10,
#        15, 10, 16, 14, 13,  8, 12, 10, 10, 13,  9,  7,  9,  9,  8, 11, 11,
#        10,  6,  4,  4, 11,  8, 11,  6, 10, 10, 12, 13,  8, 11,  6,  9,  9,
#        12, 12, 15, 11,  6,  8, 15, 14,  7,  8, 10,  9,  7, 13, 12,  8,  7,
#         9,  9, 13, 11,  6, 16, 13, 14,  6,  9, 11, 16, 16,  7, 12, 19,  8,
#         8,  9, 10,  5,  5, 12,  4, 16,  6,  7, 12,  7,  9,  9, 14, 13, 17,
#        16, 12, 10, 12, 15, 10, 11,  9, 15, 10,  5, 10, 14,  7,  8, 10,  9,
#         9,  8, 11, 10,  9,  7, 12, 11,  8,  9,  7, 10, 11, 13, 10, 10,  9,
#         7, 12,  7, 13, 10, 10, 10, 15,  5,  4, 13,  5, 12, 11],
#       dtype=int64)

# %%
# Plot the distribution
sns.histplot
##put normal curve with mean, std
# Out:
# <Axes: ylabel='Count'>

# %%
# importing data and creating dataframe
import pandas as pd
ct_df = pd.read_csv('ct_covid19_test_data.csv')

# %%
ct_df
# Out:
#      Actual Date  Converted Date  Year  Month  Date  \
# 0      12/31/2021     2021-12-31  2021     12    31
# 1      12/31/2021     2021-12-31  2021     12    31
# 2      12/31/2021     2021-12-31  2021     12    31
# 3      12/31/2021     2021-12-31  2021     12    31
# 4      12/31/2021     2021-12-31  2021     12    31
# ...           ...            ...   ...    ...   ...
# 7699   01/01/2021     2021-01-01  2021      1     1
# 7700   01/01/2021     2021-01-01  2021      1     1
# 7701   01/01/2021     2021-01-01  2021      1     1
# 7702   01/01/2021     2021-01-01  2021      1     1
# 7703   01/01/2021     2021-01-01  2021      1     1
#
#                           County  Number of molecular tests  \
# 0                      Fairfield                       6081
# 1                       Hartford                       4907
# 2                     Litchfield                        675
# 3                      Middlesex                        794
# 4                      New Haven                       5384
# ...                          ...                        ...
# 7699                   New Haven                       1444
# 7700                  New London                        498
# 7701  Pending address validation                          0
# 7702                     Tolland                        219
# 7703                     Windham                        110
#
#       Number of molecular positives  Number of molecular negatives  \
# 0                              1940                           4125
# 1                              1602                           3291
# 2                               174                            499
# 3                               233                            559
# 4                              1513                           3860
# ...                             ...                            ...
# 7699                            144                           1299
# 7700                             54                            443
# 7701                              0                              0
# 7702                             17                            202
# 7703                             23                             86
#
#       Number of molecular indeterminates  Number of antigen tests  \
# 0                                     16                     1887
# 1                                     14                     1537
# 2                                      2                      344
# 3                                      2                      124
# 4                                     11                     1571
# ...                                  ...                      ...
# 7699                                   1                      566
# 7700                                   1                       91
# 7701                                   0                        0
# 7702                                   0                       29
# 7703                                   1                       49
#
#       Number of antigen positives  Number of antigen negatives  \
# 0                             495                         1392
# 1                             270                         1267
# 2                              77                          267
# 3                              22                          102
# 4                             356                         1215
# ...                           ...                          ...
# 7699                           42                          524
# 7700                           15                           76
# 7701                            0                            0
# 7702                            5                           24
# 7703                            5                           44
#
#       Number of antigen indeterminates
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 7699                                 0
# 7700                                 0
# 7701                                 0
# 7702                                 0
# 7703                                 0
#
# [7704 rows x 14 columns]

# %%
ct_df_2021 = ct_df.loc['01/01/2021':'12/31/2021']

# %%
ct_df_2021 = ct_df[(ct_df['Converted Date']>='2021-01-01') & (ct_df['Converted Date']<='2021-12-31')]

# %%
ct_df_2021
# Out:
#      Actual Date  Converted Date  Year  Month  Date  \
# 0      12/31/2021     2021-12-31  2021     12    31
# 1      12/31/2021     2021-12-31  2021     12    31
# 2      12/31/2021     2021-12-31  2021     12    31
# 3      12/31/2021     2021-12-31  2021     12    31
# 4      12/31/2021     2021-12-31  2021     12    31
# ...           ...            ...   ...    ...   ...
# 7699   01/01/2021     2021-01-01  2021      1     1
# 7700   01/01/2021     2021-01-01  2021      1     1
# 7701   01/01/2021     2021-01-01  2021      1     1
# 7702   01/01/2021     2021-01-01  2021      1     1
# 7703   01/01/2021     2021-01-01  2021      1     1
#
#                           County  Number of molecular tests  \
# 0                      Fairfield                       6081
# 1                       Hartford                       4907
# 2                     Litchfield                        675
# 3                      Middlesex                        794
# 4                      New Haven                       5384
# ...                          ...                        ...
# 7699                   New Haven                       1444
# 7700                  New London                        498
# 7701  Pending address validation                          0
# 7702                     Tolland                        219
# 7703                     Windham                        110
#
#       Number of molecular positives  Number of molecular negatives  \
# 0                              1940                           4125
# 1                              1602                           3291
# 2                               174                            499
# 3                               233                            559
# 4                              1513                           3860
# ...                             ...                            ...
# 7699                            144                           1299
# 7700                             54                            443
# 7701                              0                              0
# 7702                             17                            202
# 7703                             23                             86
#
#       Number of molecular indeterminates  Number of antigen tests  \
# 0                                     16                     1887
# 1                                     14                     1537
# 2                                      2                      344
# 3                                      2                      124
# 4                                     11                     1571
# ...                                  ...                      ...
# 7699                                   1                      566
# 7700                                   1                       91
# 7701                                   0                        0
# 7702                                   0                       29
# 7703                                   1                       49
#
#       Number of antigen positives  Number of antigen negatives  \
# 0                             495                         1392
# 1                             270                         1267
# 2                              77                          267
# 3                              22                          102
# 4                             356                         1215
# ...                           ...                          ...
# 7699                           42                          524
# 7700                           15                           76
# 7701                            0                            0
# 7702                            5                           24
# 7703                            5                           44
#
#       Number of antigen indeterminates
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 7699                                 0
# 7700                                 0
# 7701                                 0
# 7702                                 0
# 7703                                 0
#
# [3285 rows x 14 columns]

# %%
ct_df_2021_newlondon = ct_df_2021[ct_df_2021["County"]=="New London"]
ct_df_2021_hartford = ct_df_2021[ct_df_2021["County"]=="Hartford"]
ct_df_2021_fairfield = ct_df_2021[ct_df_2021["County"]=="Fairfield"]
ct_df_2021_litchfield = ct_df_2021[ct_df_2021["County"]=="Litchfield"]
ct_df_2021_middlesex = ct_df_2021[ct_df_2021["County"]=="Middlesex"]
ct_df_2021_newhaven = ct_df_2021[ct_df_2021["County"]=="New Haven"]

# %%
num_mol_positive_ct_df_2021_hartford = ct_df_2021_hartford['Number of molecular positives']
num_mol_positive_ct_df_2021_hartford.mean()
#sampleOne = cumulative_cases.sample(50)
# Out:
# 250.9041095890411

# %%
num_mol_positive_ct_df_2021_newlondon = ct_df_2021_newlondon['Number of molecular positives']
num_mol_positive_ct_df_2021_newlondon.mean()
# Out:
# 78.42191780821918

# %%
print("New London:",ct_df_2021_newlondon['Number of molecular positives'].mean())
print("Hartford:",ct_df_2021_hartford['Number of molecular positives'].mean())
print("Fairfield:",ct_df_2021_fairfield['Number of molecular positives'].mean())
print("Litchfield:",ct_df_2021_litchfield['Number of molecular positives'].mean())
print("Middlesex:",ct_df_2021_middlesex['Number of molecular positives'].mean())
print("New Haven",ct_df_2021_newhaven['Number of molecular positives'].mean())
# Out:
# New London: 78.42191780821918
# Hartford: 250.9041095890411
# Fairfield: 277.8383561643836
# Litchfield: 43.942465753424656
# Middlesex: 38.99452054794521
# New Haven 276.786301369863

# %%
ct_df_2021['Number of molecular positives'].mean()
# Out:
# 115.1193302891933

# %%
data_500 = [ct_df_2021['Number of molecular positives'].sample(500).mean() for i in range(0, 5000)]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(data_500, edgecolor = 'black', linewidth = 1.2)
plt.show();

# %%
import pandas as pd
import requests
import io
import warnings
import seaborn as sns
import numpy as np
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt

data_1000 = [ct_df_2021['Number of molecular positives'].sample(1000).mean() for i in range(0, 5000)]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(data_1000, edgecolor = 'black', linewidth = 1.2)
plt.show();

# %%
data_1500 = [ct_df_2021['Number of molecular positives'].sample(1500).mean() for i in range(0, 5000)]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(data_1500, edgecolor = 'black', linewidth = 1.2)
plt.show();

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(ct_data_2021_num_mol_pos, hist=False, label='normal')
#sns.distplot(ct_df_2021(n=100, p=0.5, size=1000), hist=False, label='binomial')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/troyhector/Documents/StClair/DAB501 - Stats/GroupProjectTwo/Binomial_Distribution_Project.ipynb Cell 101 line 5
#       <a href='vscode-notebook-cell:/Users/troyhector/Documents/StClair/DAB501%20-%20Stats/GroupProjectTwo/Binomial_Distribution_Project.ipynb#Y202sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/Users/troyhector/Documents/StClair/DAB501%20-%20Stats/GroupProjectTwo/Binomial_Distribution_Project.ipynb#Y202sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/Users/troyhector/Documents/StClair/DAB501%20-%20Stats/GroupProjectTwo/Binomial_Distribution_Project.ipynb#Y202sZmlsZQ%3D%3D?line=4'>5</a> sns.distplot(ct_data_2021_num_mol_pos, hist=False, label='normal')
#
# NameError: name 'ct_data_2021_num_mol_pos' is not defined

# %%
print("Number of Test Issues:", ct_df_2021['Number of molecular tests'].sum())
print("Number of Positive Test:", ct_df_2021['Number of molecular positives'].sum())
# Out:
# Number of Test Issues: 7752174
# Number of Positive Test: 378167

# %%
prob_positive = ct_df_2021['Number of molecular positives'].sum()/ct_df_2021['Number of molecular tests'].sum()
prob_positive
# Out:
# 0.04878205778146878

# %%
hartford_prob_positive = ct_df_2021_hartford['Number of molecular positives'].sum()/ct_df_2021_hartford['Number of molecular tests'].sum()
hartford_prob_positive
# Out:
# 0.050828248473432

# %%
from scipy.stats import binom
print(binom.pmf(k=250, n=5000, p=hartford_prob_positive))
# Out:
# 0.02496979225407874

# %%
from scipy.stats import binom
# Assign and print probability of 250 positive our of 500 test issues
print(binom.pmf(k=250, n=500, p=prob_positive))
# Out:
# 5.038174332017633e-185

# %%
from scipy.stats import binom 
n = 100
p = hartford_prob_positive
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
plt.bar(r_values, dist) 
plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(ct_df_2021['Number of molecular positives'])

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(ct_df_2021_hartford['Number of molecular positives'])

plt.show()

# %%
ct_df_2021_hartford.describe()
# Out:
#          Year       Month        Date  Number of molecular tests  \
# count   365.0  365.000000  365.000000                 365.000000
# mean   2021.0    6.526027   15.720548                4936.312329
# std       0.0    3.452584    8.808321                2906.455165
# min    2021.0    1.000000    1.000000                 575.000000
# 25%    2021.0    4.000000    8.000000                2487.000000
# 50%    2021.0    7.000000   16.000000                4383.000000
# 75%    2021.0   10.000000   23.000000                6683.000000
# max    2021.0   12.000000   31.000000               12958.000000
#
#        Number of molecular positives  Number of molecular negatives  \
# count                     365.000000                     365.000000
# mean                      250.904110                    4681.706849
# std                       371.001494                    2735.328813
# min                         3.000000                     571.000000
# 25%                        89.000000                    2359.000000
# 50%                       159.000000                    4062.000000
# 75%                       251.000000                    6328.000000
# max                      3274.000000                   12346.000000
#
#        Number of molecular indeterminates  Number of antigen tests  \
# count                          365.000000               365.000000
# mean                             3.701370               940.583562
# std                              4.970918               531.608684
# min                              0.000000                89.000000
# 25%                              1.000000               477.000000
# 50%                              2.000000               883.000000
# 75%                              5.000000              1257.000000
# max                             39.000000              2850.000000
#
#        Number of antigen positives  Number of antigen negatives  \
# count                   365.000000                   365.000000
# mean                     39.243836                   900.608219
# std                      51.800104                   502.725989
# min                       0.000000                    87.000000
# 25%                      17.000000                   452.000000
# 50%                      29.000000                   847.000000
# 75%                      44.000000                  1218.000000
# max                     434.000000                  2426.000000
#
#        Number of antigen indeterminates
# count                        365.000000
# mean                           0.731507
# std                            3.720927
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                           30.000000

# %%
hartford_data_100 = [ct_df_2021_hartford['Number of molecular positives'].sample(100).mean() for i in range(0, 5000)]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(hartford_data_100, edgecolor = 'black', linewidth = 1.2)
plt.show();

# %%
hartford_data_150 = [ct_df_2021_hartford['Number of molecular positives'].sample(150).mean() for i in range(0, 5000)]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(hartford_data_150, edgecolor = 'black', linewidth = 1.2)
plt.show();

# %%
hartford_data_200 = [ct_df_2021_hartford['Number of molecular positives'].sample(200).mean() for i in range(0, 5000)]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(hartford_data_200, edgecolor = 'black', linewidth = 1.2)
plt.show();

# %%
hartford_data_150

from scipy.stats import binom 
n = 100
p = hartford_prob_positive
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
plt.bar(r_values, dist) 
plt.show()

# %%
prob_hartford_data_150 = sum(hartford_data_150)/len(hartford_data_150)
prob_hartford_data_150
# Out:
# 250.922302666667

# %%
prob_hartford_data_100 = sum(hartford_data_100)/len(hartford_data_100)
prob_hartford_data_100
# Out:
# 251.15821600000058

# %%
prob_hartford_data_200 = (sum(hartford_data_200)/len(hartford_data_200))/100
prob_hartford_data_200
# Out:
# 2.508678800000009

# %%
hartford_prob_positive
# Out:
# 0.050828248473432

# %%
from scipy.stats import binom 
n = 500
p = hartford_prob_positive
# defining list of r values 
r_values = list(range(n + 1)) 
# list of pmf values 
dist = [binom.pmf(r, n, p) for r in r_values ] 
# plotting the graph  
plt.bar(r_values, dist) 
plt.show()

# %%
hartford_data_pos = [ct_df_2021_hartford['Number of molecular positives']]

plt.rcParams['figure.figsize'] = (10,5)
plt.hist(hartford_data_pos, edgecolor = 'black', linewidth = 1.2, bins = 30)
plt.show();
